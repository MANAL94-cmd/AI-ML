# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)# Adding nice back ground to the graphs
import scipy.stats       as stats

# %%
PartA Answers

# %%
#Question 1 Answers
#read csv file
file="PA1.csv"
purchase_list=pd.read_csv(file)

#Qn_1.A "joint probability of the people who planned to purchase and actually placed an order"
Answer_1A=purchase_list['Actually placed order for Product A - Yes'][0]/purchase_list['total'][2]

print(' 1A) joint probability of the people who planned to purchase and actually placed an order %1.4f'% Answer_1A)
#joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase
Answer_1B=purchase_list['Actually placed order for Product A - Yes'][0]/purchase_list['total'][0]
print(' 1B) joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase %1.4f'% Answer_1B)
# Out:
#  1A) joint probability of the people who planned to purchase and actually placed an order 0.2000
#  1B) joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase 0.8000

# %%
#Question 2 Answers
Failure_rate=0.05
Random_sample=10
k   =  np.arange(0,Random_sample+1) # An array of quantiles
binomial = stats.binom.pmf(k,Random_sample,Failure_rate)

print(binomial)

#2.A. Probability that none of the items are defective? 
print(' 2A) Probability that none of the items are defective %1.4f'% binomial[0])

#2.B. Probability that exactly one of the items is defective?
print(' 2B) Probability that exactly one of the items is defective %1.4f'% binomial[1])
#2.C. Probability that two or fewer of the items are defective?
#calculating cumulative binomial cumbinomial = stats.binom.cdf(k,n,p)
cumbinomial = stats.binom.cdf(k,Random_sample,Failure_rate)
print(cumbinomial)
print(' 2C) Probability that two or fewer of the items are defective %1.4f'% cumbinomial[2])
#2.D. Probability that three or more of the items are defective ? 
P = 1- cumbinomial[2]
print(' 2D) Probability that three or more of the items are defective %1.4f'% P)
# Out:
# [5.98736939e-01 3.15124705e-01 7.46347985e-02 1.04750594e-02
#  9.64808106e-04 6.09352488e-05 2.67259863e-06 8.03789062e-08
#  1.58642578e-09 1.85546875e-11 9.76562500e-14]
#  2A) Probability that none of the items are defective 0.5987
#  2B) Probability that exactly one of the items is defective 0.3151
# [0.59873694 0.91386164 0.98849644 0.9989715  0.99993631 0.99999725
#  0.99999992 1.         1.         1.         1.        ]
#  2C) Probability that two or fewer of the items are defective 0.9885
#  2D) Probability that three or more of the items are defective 0.0115

# %%
#Question 3 Answers
rate=3 #Average sales per week
#3.A.What is Probability that in a given week he will sell some cars
n    =  np.arange(0,16)
cumpoisson = stats.poisson.cdf(n,rate)

P_selling_no_cars=cumpoisson[0]
P_selling_some_cars=1-P_selling_no_cars

print(' 3A) Probability that a given week he will sell some cars %1.4f' % P_selling_some_cars)

#3.B. What is Probability that in a given week he will sell 2 or more but less than 5 cars
P_selling_2_3_4_cars=cumpoisson[2]+cumpoisson[3]+cumpoisson[4]

print(' 3A) Probability that in a given week he will sell 2 or more but less than 5 cars %1.4f' % P_selling_2_3_4_cars)

#3.C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week

poisson = stats.poisson.pmf(n,rate)

plt.plot(n,poisson, 'o-')
plt.title('Poisson')
plt.xlabel('number of cars sold per week')
plt.ylabel('cumulative probability of cars sold per-week')
plt.show()
# Out:
#  3A) Probability that a given week he will sell some cars 0.9502
#  3A) Probability that in a given week he will sell 2 or more but less than 5 cars 1.8857

# %%
#Question 4 Answers

Accuracy_rate=0.868
Random_sample=3
k   =  np.arange(0,Random_sample+1) # An array of quantiles
binomial = stats.binom.pmf(k,Random_sample,Accuracy_rate)
print(binomial)

#4.A. What is the probability that all three orders will be recognised correctly?

print(' 4A) probability that all three orders will be recognised correctly %1.4f'% binomial[3])

#4.B. What is the probability that none of the three orders will be recognised correctly
print(' 4B) probability that none of the three orders will be recognised correctly %1.4f'% binomial[0])

#4.C. What is the probability that at least two of the three orders will be recognised correctly?
binomial=binomial[2]+binomial[3]
print(' 4C) probability that at least two of the three orders will be recognised correctly %1.4f'% binomial)
# Out:
# [0.00229997 0.0453721  0.2983559  0.65397203]
#  4A) probability that all three orders will be recognised correctly 0.6540
#  4B) probability that none of the three orders will be recognised correctly 0.0023
#  4C) probability that at least two of the three orders will be recognised correctly 0.9523

# %%
#Question 5 Answers
Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of
Applied Statistics to get data driven business solution

***********************
Let’s say that 80% of all business startups in the IT industry report that they generate a profit in their first year. If a sample of 10 new IT business startups is selected, find the probability that exactly seven will generate a profit in their first year.

# %%
PartB Answers

# %%
#cleaning the data and prepare final dataset to be used for analysis.

# Reading Raw data set
file="DS+-+Part2+-+Basketball.csv"
df=pd.read_csv(file)
print(df)

#Finding the mean score to filter out teams below mean score
mean_Score=np.mean(df["Score"])
print(' mean_Score %1.4f'% mean_Score)

#Deleting teams with scores below mean score
df.drop(df[df['Score'] < mean_Score].index, inplace = True)
print(df)
mean_BasketScored=np.mean(df["BasketScored"])
print(' mean_BasketScored %1.4f'% mean_BasketScored)
df.drop(df[df['BasketScored'] < mean_BasketScored].index, inplace = True)
#Printing cleaned data set
print(df)
# Out:
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# ..      ...         ...    ...          ...       ...         ...        ...
# 56  Team 57           1     34           38         8          10         20
# 57  Team 58           1     22           30         7           8         15
# 58  Team 59           1     19           30         7           5         18
# 59  Team 60           1     14           30         5           4         21
# 60  Team 61           1      0            0         0           0          0
#
#     BasketScored  BasketGiven  TournamentChampion  Runner0up TeamLaunch  \
# 0           5947         3140                  33         23       1929
# 1           5900         3114                  25         25       1929
# 2           4534         3309                  10          8       1929
# 3           4398         3469                   6          6   1931to32
# 4           4631         3700                   8          7       1929
# ..           ...          ...                 ...        ...        ...
# 56            38           66                   0          0    2009-10
# 57            37           57                   0          0    1956-57
# 58            51           85                   0          0    1951~52
# 59            34           65                   0          0    1955-56
# 60             0            0                   0          0    2017~18
#
#     HighestPositionHeld
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 56                   20
# 57                   16
# 58                   16
# 59                   15
# 60                    9
#
# [61 rows x 13 columns]
#  mean_Score 901.4262
#        Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0    Team 1          86   4385         2762      1647         552        563
# 1    Team 2          86   4262         2762      1581         573        608
# 2    Team 3          80   3442         2614      1241         598        775
# 3    Team 4          82   3386         2664      1187         616        861
# 4    Team 5          86   3368         2762      1209         633        920
# 5    Team 6          73   2819         2408       990         531        887
# 6    Team 7          82   2792         2626       948         608       1070
# 7    Team 8          70   2573         2302       864         577        861
# 8    Team 9          58   2109         1986       698         522        766
# 9   Team 10          51   1884         1728       606         440        682
# 10  Team 11          45   1814         1530       563         392        575
# 11  Team 12          51   1789         1698       586         389        723
# 12  Team 13          42   1471         1466       463         384        619
# 13  Team 14          44   1416         1428       453         336        639
# 14  Team 15          43   1389         1458       471         358        629
# 15  Team 16          37   1351         1318       426         327        565
# 16  Team 17          36   1314         1255       390         330        535
# 17  Team 18          38   1174         1192       408         292        492
# 18  Team 19          27   1148          988       333         256        399
# 19  Team 20          33   1020         1096       367         242        487
# 20  Team 21          17    970          646       266         172        208
#
#     BasketScored  BasketGiven  TournamentChampion  Runner0up TeamLaunch  \
# 0           5947         3140                  33         23       1929
# 1           5900         3114                  25         25       1929
# 2           4534         3309                  10          8       1929
# 3           4398         3469                   6          6   1931to32
# 4           4631         3700                   8          7       1929
# 5           3680         3373                   1          4    1934-35
# 6           3609         3889                   0          0       1929
# 7           3228         3230                   2          3       1929
# 8           2683         2847                   0          1    1939-40
# 9           2159         2492                   1          0    1932-33
# 10          2052         2188                   1          5   1941to42
# 11          2278         2624                   0          0    1939-40
# 12          1767         2180                   0          0    1948-49
# 13          1843         2368                   0          1       1929
# 14          1753         2152                   0          1    1944_45
# 15          1500         1834                   0          0    1935-36
# 16          1421         1763                   0          0    1949_50
# 17          1642         1951                   0          0   1933to34
# 18          1182         1371                   0          0    1960-61
# 19          1347         1746                   0          1    1951-52
# 20           892          789                   0          1    1998-99
#
#     HighestPositionHeld
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# 5                     1
# 6                     3
# 7                     1
# 8                     2
# 9                     1
# 10                    1
# 11                    4
# 12                    4
# 13                    2
# 14                    2
# 15                    4
# 16                    4
# 17                    3
# 18                    3
# 19                    2
# 20                    2
#  mean_BasketScored 2783.1429
#      Team  Tournament  Score  PlayedGames  WonGames  DrawnGames  LostGames  \
# 0  Team 1          86   4385         2762      1647         552        563
# 1  Team 2          86   4262         2762      1581         573        608
# 2  Team 3          80   3442         2614      1241         598        775
# 3  Team 4          82   3386         2664      1187         616        861
# 4  Team 5          86   3368         2762      1209         633        920
# 5  Team 6          73   2819         2408       990         531        887
# 6  Team 7          82   2792         2626       948         608       1070
# 7  Team 8          70   2573         2302       864         577        861
#
#    BasketScored  BasketGiven  TournamentChampion  Runner0up TeamLaunch  \
# 0          5947         3140                  33         23       1929
# 1          5900         3114                  25         25       1929
# 2          4534         3309                  10          8       1929
# 3          4398         3469                   6          6   1931to32
# 4          4631         3700                   8          7       1929
# 5          3680         3373                   1          4    1934-35
# 6          3609         3889                   0          0       1929
# 7          3228         3230                   2          3       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# 5                    1
# 6                    3
# 7                    1

# %%
#Perform detailed statistical analysis and EDA using univariate, bi-variate and multivariate EDA techniques to get data driven insights on
#recommending which teams they can approach which will be a deal win for them. Also as a data and statistics expert you have to develop a
#detailed performance report using this data'

#sns.distplot(df['BasketScored'],kde=True,color='black',bins=10)
#sns.lineplot(data = df,x="Team",y="Score");
sns.lineplot(data = df,x="Team",y="Tournament");
sns.displot(df['Score'],kde=True,color='black',bins=10);

sns.displot(df['Tournament'],kde=True,color='green',bins=10);

sns.displot(df['BasketScored'],kde=True,color='blue',bins=10);
sns.jointplot(data = df,x="Team",y="Tournament");
sns.jointplot(data = df,x="Tournament",y="TournamentChampion");
#sns.jointplot(data = df,x="Tournament",y="BasketGiven",kind="hex");
sns.jointplot(data = df,x="Tournament",y="BasketGiven", kind="kde");

sns.pairplot(df[['Tournament','Score','BasketScored']]);

# %%
#PartC Answers

# %%
# Reading Raw data set
file="DS+-+Part3+-+CompanyX_EU.csv"
df=pd.read_csv(file)
print(df)

#Check the datatypes of each attribute.
datatypes = df.dtypes
print(datatypes)

#Check for null values in the attributes
pd.isnull(df)
#Drop the null values.
df = df.dropna(axis=0)
print(df)
#Convert the ‘Funding’ features to a numerical value.
df1.loc[:,'Funds_in_million'] == df1['Funding'].apply(lambda x: float(x[1:-1])/1000 if x[-1] == 'K' else (float(x[1:-1])*1000 if x[-1] == 'B' else float(x[1:-1])))
print(df1)

#plot box plots for funds in million
boxplot = df1.boxplot(column=['Funds_in_million']);

#Check the number of outliers greater than the upper fence.
q3, q1 = np.percentile(df1['Funds_in_million'], [75 ,25])
iqr = q3 - q1
print(iqr);
Upper_Fence=q3+1.5*iqr
print(Upper_Fence);
df2=df1['Funds_in_million'][df1['Funds_in_million']>Upper_Fence]
print(df2)
count=df2.count()
print(' number of outliers greater than the upper fence %d'% count)

#Check frequency of the OperatingState features classes
#Is there any significant difference between Funds raised by companies that are still operating vs companies that closed down?
df3=df1['Funds_in_million'][df1['OperatingState']=='Operating']
print(df3)
df4=df1['Funds_in_million'][df1['OperatingState']=='Closed']
print(df4)
Operating_sum=sum(df3)
print(Operating_sum)
Closed_sum=sum(df4)
print(Closed_sum)
Difference=Operating_sum-Closed_sum
print(' difference between Funds raised by companies that are still operating vs companies that closed down are millions of %1.4f'% Difference)

#Write the null hypothesis and alternative hypothesis
#Test for significance and conclusion
# Make a copy of the original data frame.
df_Copy = df.copy()
print(df_Copy)

#Check frequency distribution of Result variables.
#Calculate percentage of winners that are still operating and percentage of contestants that are still operating 
df5=df1[df1['OperatingState']=='Operating']
df6=df5['Result'][df5['Result']=='Winner']
df7=df5['Result'][df5['Result']=='Contestant']
print(df5)
print(df6)
print(df7)
Count_Oper=df5['OperatingState'].count()
print(Count_Oper)
Count_Winner_Oper=df6.count()
print(Count_Winner_Oper)
Count_Contestant_Oper=df7.count()
print(Count_Contestant_Oper)

Per_Winner_Oper=(Count_Winner_Oper/Count_Oper)*100
Per_Contestant_Oper=(Count_Contestant_Oper/Count_Oper)*100
print(' percentage of winners that are still operating  %1.4f'% Per_Winner_Oper)
print(' percentage of contestants that are still operating  %1.4f'% Per_Contestant_Oper)

#Write your hypothesis comparing the proportion of companies that are operating between winners and contestants:
#Test for significance and conclusion 
#Select only the Event that has ‘disrupt’ keyword from 2013 onwards.
# Out:
#              Startup             Product Funding             Event  \
# 0             2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1               3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2        3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3         3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4    42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
# ..               ...                 ...     ...               ...
# 657           Zivity          zivity.com     $8M         TC40 2007
# 658           Zmorph        zmorph3d.com     $1M                 -
# 659           Zocdoc          zocdoc.com   $223M         TC40 2007
# 660             Zula         zulaapp.com   $3.4M   Disrupt SF 2013
# 661           Zumper          zumper.com  $31.5M   Disrupt SF 2012
#
#               Result OperatingState
# 0         Contestant      Operating
# 1         Contestant         Closed
# 2         Contestant      Operating
# 3    Audience choice      Operating
# 4         Contestant      Operating
# ..               ...            ...
# 657       Contestant      Operating
# 658  Audience choice      Operating
# 659       Contestant      Operating
# 660  Audience choice      Operating
# 661         Finalist      Operating
#
# [662 rows x 6 columns]
# Startup           object
# Product           object
# Funding           object
# Event             object
# Result            object
# OperatingState    object
# dtype: object
#           Startup          Product Funding                      Event  \
# 1            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 3      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 5            5to1         5to1.com  $19.3M                  TC50 2009
# 6    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 10     AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 657        Zivity       zivity.com     $8M                  TC40 2007
# 658        Zmorph     zmorph3d.com     $1M                          -
# 659        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 660          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 661        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState
# 1         Contestant         Closed
# 3    Audience choice      Operating
# 5         Contestant       Acquired
# 6           Finalist      Operating
# 10        Contestant      Operating
# ..               ...            ...
# 657       Contestant      Operating
# 658  Audience choice      Operating
# 659       Contestant      Operating
# 660  Audience choice      Operating
# 661         Finalist      Operating
#
# [446 rows x 6 columns]
#           Startup          Product Funding                      Event  \
# 1            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 3      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 5            5to1         5to1.com  $19.3M                  TC50 2009
# 6    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 10     AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 657        Zivity       zivity.com     $8M                  TC40 2007
# 658        Zmorph     zmorph3d.com     $1M                          -
# 659        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 660          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 661        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState  Funds_in_million
# 1         Contestant         Closed              0.63
# 3    Audience choice      Operating              1.00
# 5         Contestant       Acquired             19.30
# 6           Finalist      Operating             29.00
# 10        Contestant      Operating              1.80
# ..               ...            ...               ...
# 657       Contestant      Operating              8.00
# 658  Audience choice      Operating              1.00
# 659       Contestant      Operating            223.00
# 660  Audience choice      Operating              3.40
# 661         Finalist      Operating             31.50
#
# [446 rows x 7 columns]
# 8.72975
# 22.569625
# 6        29.0
# 31       24.0
# 40       50.9
# 49       40.0
# 56      205.0
# 108      32.5
# 113     182.1
# 128      35.4
# 130      38.0
# 132      37.1
# 138      72.0
# 139      64.0
# 154    1700.0
# 166      34.6
# 172      35.5
# 179      30.1
# 180      26.0
# 188      66.0
# 191      28.3
# 209     103.0
# 213      25.9
# 215      36.5
# 225      44.7
# 231      24.2
# 271     122.4
# 276      34.9
# 279      67.8
# 282     166.1
# 302      42.1
# 305      69.0
# 313      65.1
# 325      25.1
# 346      31.8
# 389      37.0
# 393      38.5
# 394      25.5
# 398      24.0
# 427     278.0
# 432      24.0
# 435      63.0
# 460      25.0
# 471     160.0
# 546      40.0
# 555      47.4
# 560      24.5
# 581      25.0
# 593     332.4
# 598      35.0
# 606     168.8
# 615      28.0
# 625      30.8
# 643      41.8
# 644     142.0
# 647     117.8
# 649      26.0
# 650      28.0
# 654      62.1
# 656     583.6
# 659     223.0
# 661      31.5
# Name: Funds_in_million, dtype: float64
#  number of outliers greater than the upper fence 60
# 3        1.00
# 6       29.00
# 10       1.80
# 13       1.00
# 14       0.75
#         ...
# 657      8.00
# 658      1.00
# 659    223.00
# 660      3.40
# 661     31.50
# Name: Funds_in_million, Length: 319, dtype: float64
# 1       0.6300
# 11      1.0000
# 17      0.9292
# 20      1.9000
# 34      0.6000
# 48      0.1900
# 62     20.8000
# 79      8.1000
# 82      0.3250
# 97      5.5000
# 107     0.3500
# 110     0.7500
# 112     0.4750
# 115     6.7000
# 120    12.0000
# 126     0.9250
# 148     4.0000
# 150     0.1600
# 152     0.3000
# 170     2.4000
# 172    35.5000
# 178     0.1000
# 183     2.3000
# 205     0.7000
# 210     1.2000
# 216     1.0000
# 222     0.1915
# 227     0.3000
# 248     0.1500
# 256     0.5000
# 284    10.0000
# 295     3.0000
# 317     0.8750
# 336     7.3000
# 348     3.0000
# 355     1.2000
# 388     1.0000
# 396     0.8920
# 418     3.5000
# 439     0.1500
# 443     3.5000
# 489     4.1000
# 490     1.1000
# 503     0.7000
# 524     0.2000
# 538     1.5000
# 542     0.6000
# 548     1.8000
# 564     0.3000
# 566     0.6500
# 571     4.2000
# 577     0.2800
# 583     0.0930
# 595    14.5000
# 599     0.5000
# 612     0.8000
# 645    10.0000
# Name: Funds_in_million, dtype: float64
# 6080.837200000006
# 185.7157
#  difference between Funds raised by companies that are still operating vs companies that closed down are millions of 5895.1215
#           Startup          Product Funding                      Event  \
# 1            3DLT         3dlt.com   $630K           Disrupt NYC 2013
# 3      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 5            5to1         5to1.com  $19.3M                  TC50 2009
# 6    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 10     AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# ..            ...              ...     ...                        ...
# 657        Zivity       zivity.com     $8M                  TC40 2007
# 658        Zmorph     zmorph3d.com     $1M                          -
# 659        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 660          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 661        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState
# 1         Contestant         Closed
# 3    Audience choice      Operating
# 5         Contestant       Acquired
# 6           Finalist      Operating
# 10        Contestant      Operating
# ..               ...            ...
# 657       Contestant      Operating
# 658  Audience choice      Operating
# 659       Contestant      Operating
# 660  Audience choice      Operating
# 661         Finalist      Operating
#
# [446 rows x 6 columns]
#           Startup          Product Funding                      Event  \
# 3      3Dprintler   3dprintler.com     $1M            Disrupt NY 2016
# 6    8 Securities  8securities.com    $29M       Disrupt Beijing 2011
# 10     AdhereTech   adheretech.com   $1.8M  Hardware Battlefield 2014
# 13       Agrilyst     agrilyst.com     $1M            Disrupt SF 2015
# 14          Aiden         aiden.ai   $750K        Disrupt London 2016
# ..            ...              ...     ...                        ...
# 657        Zivity       zivity.com     $8M                  TC40 2007
# 658        Zmorph     zmorph3d.com     $1M                          -
# 659        Zocdoc       zocdoc.com   $223M                  TC40 2007
# 660          Zula      zulaapp.com   $3.4M            Disrupt SF 2013
# 661        Zumper       zumper.com  $31.5M            Disrupt SF 2012
#
#               Result OperatingState  Funds_in_million
# 3    Audience choice      Operating              1.00
# 6           Finalist      Operating             29.00
# 10        Contestant      Operating              1.80
# 13            Winner      Operating              1.00
# 14        Contestant      Operating              0.75
# ..               ...            ...               ...
# 657       Contestant      Operating              8.00
# 658  Audience choice      Operating              1.00
# 659       Contestant      Operating            223.00
# 660  Audience choice      Operating              3.40
# 661         Finalist      Operating             31.50
#
# [319 rows x 7 columns]
# 13     Winner
# 127    Winner
# 166    Winner
# 209    Winner
# 244    Winner
# 280    Winner
# 296    Winner
# 302    Winner
# 308    Winner
# 351    Winner
# 374    Winner
# 389    Winner
# 474    Winner
# 486    Winner
# 500    Winner
# 598    Winner
# 623    Winner
# 650    Winner
# Name: Result, dtype: object
# 10     Contestant
# 14     Contestant
# 15     Contestant
# 16     Contestant
# 18     Contestant
#           ...
# 646    Contestant
# 649    Contestant
# 654    Contestant
# 657    Contestant
# 659    Contestant
# Name: Result, Length: 214, dtype: object
# 319
# 18
# 214
#  percentage of winners that are still operating  5.6426
#  percentage of contestants that are still operating  67.0846
